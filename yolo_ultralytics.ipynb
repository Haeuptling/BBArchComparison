# %%
import os
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

from ultralytics import YOLO
from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.0.222 🚀 Python-3.11.7 torch-2.1.1+cpu CPU (Intel Core(TM) i7-8565U 1.80GHz)
# Setup complete ✅ (8 CPUs, 15.8 GB RAM, 399.7/475.7 GB disk)

# %%
model = YOLO("yolov8m.yaml")
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
# ...

# %%
results = model.train(data="workspace/yolo_dataset/config.yaml", epochs=25)
# Out:
# Ultralytics YOLOv8.0.222 🚀 Python-3.11.7 torch-2.1.1+cpu CPU (Intel Core(TM) i7-8565U 1.80GHz)
# ...

# %%
cd \Users\alh\PycharmProjects\BBArchComparison
# Out:
# C:\Users\alh\PycharmProjects\BBArchComparison
# C:\Users\alh\PycharmProjects\BBArchComparison\venv\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
Image(filename='runs/detect/train13/confusion_matrix.png', width=600)

# %%
Image(filename='runs/detect/train13/results.png', width=600)

# %%
Image(filename='runs/detect/train13/train_batch0.jpg', width=600)

# %%
# !yolo task=detect mode=val model=runs/detect/train13/weights/best.pt data=workspace/yolo_dataset/config.yaml
# Out:
# Ultralytics YOLOv8.0.222 ðŸš€ Python-3.11.7 torch-2.1.1+cpu CPU (Intel Core(TM) i7-8565U 1.80GHz)
# YOLOv8m summary (fused): 218 layers, 25864078 parameters, 0 gradients, 78.8 GFLOPs
#                    all          2         82          0          0          0          0
# Speed: 26.8ms preprocess, 5276.0ms inference, 0.0ms loss, 9.4ms postprocess per image
# Results saved to C:\Users\alh\PycharmProjects\BBArchComparison\runs\detect\val
# ðŸ’¡ Learn more at https://docs.ultralytics.com/modes/val
# val: Scanning C:\Users\alh\PycharmProjects\BBArchComparison\workspace\yolo_dataset\val\labels.cache... 2 images, 0 backgrounds, 0 corrupt: 100%|##########| 2/2 [00:00<?, ?it/s]
# val: Scanning C:\Users\alh\PycharmProjects\BBArchComparison\workspace\yolo_dataset\val\labels.cache... 2 images, 0 backgrounds, 0 corrupt: 100%|##########| 2/2 [00:00<?, ?it/s]
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
Image(filename='runs/detect/train13/val_batch0_pred.jpg', width=600)

# %%
Image(filename='runs/detect/train13/val_batch0_labels.jpg', width=600 ,  metadata=dict(source='source', size=f'{3}') )

# %%
model = YOLO('runs/detect/train13/weights/best.pt')
model.predict('workspace/yolo_dataset/val/images/scan_0012.jpg', save_txt=True,  save_crop=True, line_width=1  )
# Out:
# image 1/1 C:\Users\alh\PycharmProjects\BBArchComparison\workspace\yolo_dataset\val\images\scan_0012.jpg: 640x384 (no detections), 776.4ms
# Speed: 7.4ms preprocess, 776.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to C:\Users\alh\PycharmProjects\BBArchComparison\runs\detect\predict2
# 0 label saved to C:\Users\alh\PycharmProjects\BBArchComparison\runs\detect\predict2\labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...
