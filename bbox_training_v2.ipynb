# %% [markdown]
# importing the required packages and libraries.

# %%
import os
import xml.etree.ElementTree as ET
import tensorflow as tf
import keras_cv

from tqdm.auto import tqdm
from tensorflow import keras
from keras_cv import bounding_box
from keras_cv import visualization
from tensorflow.keras.models import load_model
import numpy as np
from tensorflow.keras.models import Sequential, model_from_json
# Out:
# WARNING:tensorflow:From c:\Users\Tristan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Using TensorFlow backend

# %% [markdown]
# Globale Variable

# %%
# Path
gv_path_models= "workspace/models/"
gv_path_images = "workspace/images/original_name/"
gv_annotation_path= "workspace/annotations/original/pascal/"
gv_model_path = "workspace/models/detector.h5"
gv_bbox_path = "workspace/models/bbox"
WORKSPACE_PATH = 'workspace'
IMAGE_PATH = WORKSPACE_PATH+'/images'

SPLIT_RATIO = 0.2
BATCH_SIZE = 2
LEARNING_RATE = 0.001
EPOCH = 50
GLOBAL_CLIPNORM = 10.0

# %% [markdown]
# The Dataset Preparation

# %%
class_ids = [
"Ausbildung",
"Ausbildung_Klasse" ,
"Ausbildung_Antrag_gestellt_ja" ,
"Ausbildung_Antrag_gestellt_nein" ,
"Ausbildung_Amt" ,
"Ausbildung_Foerderungsnummer" ,
"Ausbilung_Abschluss" ,
"Ausbildung_Vollzeit" ,
"Ausbildung" ,
"Ausbildung_Teilzeit" ,
"Ausbildung_Staette" ,
"Person" ,
"Person_Geburtsort" ,
"Person_maennlich" ,
"Person_Geburtsdatum" ,
"Person_weiblich",
"Person_divers",
"Person_Name",
"Person_Familienstand" ,
"Person_Vorname" ,
"Person_Geburtsname" ,
"Person_Familienstand_seit",
"Person_Stattsangehörigkeit_eigene" ,
"Person_Stattsangehörigkeit_Ehegatte" ,
"Person_Kinder",
"Wohnsitz_Strasse",
"Wohnsitz_Land",
"Wohnsitz_Postleitzahl",
"Wohnsitz",
"Wohnsitz_Hausnummer",
"Wohnsitz_Adresszusatz",
"Wohnsitz_Ort",
"Wohnsitz_waehrend_Ausbildung" ,
"Wohnsitz_waehrend_Ausbildung_Strasse",
"Wohnsitz_waehrend_Ausbildung_Hausnummer",
"Wohnsitz_waehrend_Ausbildung_Land",
"Wohnsitz_waehrend_Ausbildung_Ort",
"Wohnsitz_waehrend_Ausbildung_elternwohnung_nein",
"Wohnsitz_waehrend_Ausbildung_Adresszusatz",
"Wohnsitz_waehrend_Ausbildung_Postleitzahl",
"Wohnsitz_waehrend_Ausbildung_elternmiete",
"Wohnsitz_waehrend_Ausbildung_elternwohnung_ja",
"Wohnsitz_waehrend_Ausbildung_elternmiete_nein"
]
sub_class_ids = [
"Ausbildung_Klasse" ,
"Ausbildung_Antrag_gestellt_ja" ,
"Ausbildung_Antrag_gestellt_nein" ,
"Ausbildung_Amt" ,
"Ausbildung_Foerderungsnummer" ,
"Ausbilung_Abschluss" ,
"Ausbildung_Vollzeit" ,
"Ausbildung" ,
"Ausbildung_Teilzeit" ,
"Ausbildung_Staette" ,
"Person_Geburtsort" ,
"Person_maennlich" ,
"Person_Geburtsdatum" ,
"Person_weiblich",
"Person_divers",
"Person_Name",
"Person_Familienstand" ,
"Person_Vorname" ,
"Person_Geburtsname" ,
"Person_Familienstand_seit",
"Person_Stattsangehörigkeit_eigene" ,
"Person_Stattsangehörigkeit_Ehegatte" ,
"Person_Kinder",
"Wohnsitz_Strasse",
"Wohnsitz_Land",
"Wohnsitz_Postleitzahl",
"Wohnsitz_Hausnummer",
"Wohnsitz_Adresszusatz",
"Wohnsitz_Ort",
"Wohnsitz_waehrend_Ausbildung" ,
"Wohnsitz_waehrend_Ausbildung_Strasse",
"Wohnsitz_waehrend_Ausbildung_Hausnummer",
"Wohnsitz_waehrend_Ausbildung_Land",
"Wohnsitz_waehrend_Ausbildung_Ort",
"Wohnsitz_waehrend_Ausbildung_elternwohnung_nein",
"Wohnsitz_waehrend_Ausbildung_Adresszusatz",
"Wohnsitz_waehrend_Ausbildung_Postleitzahl",
"Wohnsitz_waehrend_Ausbildung_elternmiete",
"Wohnsitz_waehrend_Ausbildung_elternwohnung_ja",
"Wohnsitz_waehrend_Ausbildung_elternmiete_nein"
]
main_class_ids=[
    #"Ausbildung",
    "Person" ,
    "Wohnsitz",
]

class_mapping = dict(zip(range(len(class_ids)), class_ids))
main_class_mapping = dict(zip(range(len(main_class_ids)), main_class_ids))
sub_class_mapping = dict(zip(range(len(sub_class_ids)), sub_class_ids))

# %%
# Get all XML file paths in path_annot and sort them
xml_files = sorted(
    [
        os.path.join(gv_annotation_path, file_name)
        for file_name in os.listdir(gv_annotation_path)
        if file_name.endswith(".xml")
    ]
)
 
# Get all JPEG image file paths in path_images and sort them
jpg_files = sorted(
    [
        os.path.join(gv_path_images, file_name)
        for file_name in os.listdir(gv_path_images)
        if file_name.endswith(".jpg")
    ]
)

# %% [markdown]
# parsing the XML annotation files

# %%
def map_class_id(classes, cls):    
    class_ids = [
        list(class_mapping.keys())[list(class_mapping.values()).index(cls)]
        for cls in classes
    ]
    return class_ids

def create_box(bbox):
    xmin = float(bbox.find("xmin").text)
    ymin = float(bbox.find("ymin").text)
    xmax = float(bbox.find("xmax").text)
    ymax = float(bbox.find("ymax").text)
    return [xmin, ymin, xmax, ymax]

# %%
def parse_annotation(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
 
    image_name = root.find("filename").text
    image_path = os.path.join(gv_path_images, image_name)
    
    boxes = []
    classes = []
    main_classes = []
    sub_classes = []
    main_boxes = []
    sub_boxes = []
    for obj in root.iter("object"):
        cls = obj.find("name").text
        classes.append(cls)
 
        bbox = obj.find("bndbox")
        boxes.append( create_box(bbox))
        #main labels
        #(cls=='Ausbildung') or
        if  (cls =='Person') or (cls == 'Wohnsitz'):
            main_classes.append(cls)
            bbox = obj.find("bndbox")
            main_boxes.append( create_box(bbox))
        else:
            bbox = obj.find("bndbox")
            sub_boxes.append( create_box(bbox))
            sub_classes.append(cls)

    class_ids = map_class_id(classes, cls)
    main_class_ids = map_class_id(main_classes, cls)            
    sub_class_ids = map_class_id(sub_classes, cls)

    return image_path, boxes, class_ids, main_class_ids, sub_class_ids, main_boxes, sub_boxes, image_name

# %%
image_paths = []
image_names = []
bbox = []
classes = []
main_classes = []
sub_classes= []
main_bbox= []
sub_bbox= []
for xml_file in tqdm(xml_files):
    image_path, boxes, class_ids, main_class_ids,sub_class_ids, main_boxes, sub_boxes, image_name = parse_annotation(xml_file)
    image_paths.append(image_path)
    bbox.append(boxes)
    classes.append(class_ids)
    image_names.append(image_name)

    main_classes.append(main_class_ids)
    sub_classes.append(sub_class_ids)
    main_bbox.append(main_boxes)
    sub_bbox.append(sub_boxes)
# Out:
#   0%|          | 0/17 [00:00<?, ?it/s]

# %%
#TODO class id von main_class und suB_class müssn von 0 beginnen

# %%
def forming_main_class_labels(array):
    for i in range(len(array)):
        for j in range(len(array[i])):
           # if array[i][j] == 10:
               # array[i][j] = 0
            if array[i][j] == 11:
                array[i][j] = 0
            if array[i][j] == 28:
                array[i][j] = 1
    return array

def forming_sub_class_labels(array):
    for i in range(len(array)):
        for j in range(len(array[i])):
            #TODO Klasse Ausbildung 
            if array[i][j] > 28:
                array[i][j] = array[i][j]-1
            if (array[i][j] > 11) and (array[i][j] < 28):
               array[i][j] = array[i][j]-2
    return array

main_classes = forming_main_class_labels(main_classes)
print(sub_classes)
sub_classes = forming_sub_class_labels(sub_classes)
print((sub_classes))
# Out:
# [[0, 10, 1, 1, 17, 19, 20, 12, 15, 13, 16, 14, 18, 21, 22, 23, 24, 25, 29, 30, 30, 27, 31, 32, 33, 34, 38, 35, 39, 36, 41, 41, 41, 41, 2, 3, 7, 9, 4, 5], [17, 19, 20, 12, 15, 13, 16, 14, 18, 21, 22, 23, 24, 25, 29, 30, 30, 27, 31, 32, 33, 34, 38, 35, 39, 36, 41, 41, 41, 41, 2, 3, 7, 9, 4, 5, 10, 1, 6], [17, 19, 20, 12, 15, 13, 16, 14, 18, 21, 22, 23, 24, 25, 29, 30, 30, 27, 31, 32, 33, 34, 38, 35, 39, 36, 41, 41, 41, 41, 2, 3, 7, 9, 4, 5, 10, 1, 6], [17, 19, 20, 12, 15, 13, 16, 14, 18, 21, 22, 23, 24, 25, 29, 30, 30, 27, 31, 32, 33, 34, 38, 35, 39, 36, 41, 41, 41, 41, 2, 3, 7, 9, 4, 5, 10, 1, 6], [17, 19, 20, 12, 15, 13, 16, 14, 18, 21, 22, 23, 24, 25, 29, 30, 30, 27, 31, 32, 33, 34, 38, 35, 39, 36, 41, 41, 41, 41, 2, 3, 7, 9, 4, 5, 10, 1, 6], [17, 19, 20, 12, 15, 13, 16, 14, 18, 21, 22, 23, 24, 25, 29, 30, 30, 27, 31, 32, 33, 34, 38, 35, 39, 36, 41, 41, 41, 41, 2, 3, 7, 9, 4, 5, 10, 1, 6], [17, 19, 20, 12, 15, 13, 16, 14, 18, 21, 22, 23, 24, 25, 29, 30, 30, 27, 31, 32, 33, 34, 38, 35, 39, 36, 41, 41, 41, 41, 2, 3, 7, 9, 4, 5, 10, 1, 6], [17, 19, 20, 12, 15, 13, 16, 14, 18, 21, 22, 23, 24, 25, 29, 30, 30, 27, 31, 32, 33, 34, 38, 35, 39, 36, 41, 41, 41, 41, 2, 3, 7, 9, 4, 5, 10, 1, 6], [17, 19, 20, 12, 15, 13, 16, 14, 18, 21, 22, 23, 24, 25, 29, 30, 30, 27, 31, 32, 33, 34, 38, 35, 39, 36, 41,
 13, 11, 14, 12, 16, 19, 20, 21, 22, 23, 28, 29, 29, 25, 30, 31, 32, 33, 37, 34, 38, 35, 40, 40, 40, 40, 2, 3, 7, 9, 4, 5, 10, 1, 6], [15, 17, 18, 10, 13, 11, 14, 12, 16, 19, 20, 21, 22, 23, 28, 29, 29, 25, 30, 31, 32, 33, 37, 34, 38, 35, 40, 40, 40, 40, 2, 3, 7, 9, 4, 5, 10, 1, 6], [15, 17, 18, 10, 13, 11, 14, 12, 16, 19, 20, 21, 22, 23, 28, 29, 29, 25, 30, 31, 32, 33, 37, 34, 38, 35, 40, 40, 40, 40, 2, 3, 7, 9, 4, 5, 10, 1, 6], [15, 17, 18, 10, 13, 11, 14, 12, 16, 19, 20, 21, 22, 23, 28, 29, 29, 25, 30, 31, 32, 33, 37, 34, 38, 35, 40, 40, 40, 40, 2, 3, 7, 9, 4, 5, 10, 1, 6], [15, 17, 18, 10, 13, 11, 14, 12, 16, 19, 20, 21, 22, 23, 28, 29, 29, 25, 30, 31, 32, 33, 37, 34, 38, 35, 40, 40, 40, 40, 2, 3, 7, 9, 4, 5, 10, 1, 6], [15, 17, 18, 10, 13, 11, 14, 12, 16, 19, 20, 21, 22, 23, 28, 29, 29, 25, 30, 31, 32, 33, 37, 34, 38, 35, 40, 40, 40, 40, 2, 3, 7, 9, 4, 5, 10, 1, 6], [15, 17, 18, 10, 13, 11, 14, 12, 16, 19, 20, 21, 22, 23, 28, 29, 29, 25, 30, 31, 32, 33, 37, 34, 38, 35, 40, 40, 40, 40, 2, 3, 7, 9, 4, 5, 10, 1, 6], [15, 17, 18, 10, 13, 11, 14, 12, 16, 19, 20, 21, 22, 23, 28, 29, 29, 25, 30, 31, 32, 33, 37, 34, 38, 35, 40, 40, 40, 40, 2, 3, 7, 9, 4, 5, 10, 1, 6], [15, 17, 18, 10, 13, 11, 14, 12, 16, 19, 20, 21, 22, 23, 28, 29, 29, 25, 30, 31, 32, 33, 37, 34, 38, 35, 40, 40, 40, 40, 2, 3, 7, 9, 4, 5, 10, 1, 6], [15, 17, 18, 10, 13, 11, 14, 12, 16, 19, 20, 21, 22, 23, 28, 29, 29, 25, 30, 31, 32, 33, 37, 34, 38, 35, 40, 40, 40, 40, 2, 3, 7, 9, 4, 5, 10, 1, 6], [15, 17, 18, 10, 13, 11, 14, 12, 16, 19, 20, 21, 22, 23, 28, 29, 29, 25, 30, 31, 32, 33, 37, 34, 38, 35, 40, 40, 40, 40, 2, 3, 7, 9, 4, 5, 10, 1, 6], [15, 17, 18, 10, 13, 11, 14, 12, 16, 19, 20, 21, 22, 23, 28, 29, 29, 25, 30, 31, 32, 33, 37, 34, 38, 35, 40, 40, 40, 40, 2, 3, 7, 9, 4, 5, 10, 1, 6]]

# %%
#TODO wie berechnen, mit offset?
#Create Images from main_classes
import cv2
IMAGES_MAIN_CLASSES_PATH = IMAGE_PATH +'/640x640_main_classes'

def create_main_images(input_path, output_path, box):
    startY, endY, startX, endX = int(np.round(box[1])), int(np.round(box[3])), int(np.round(box[0])), int(np.round(box[2]))
    image =  cv2.imread(input_path)
    cropped_image = image[startY:endY, startX:endX]
    cv2.imwrite(output_path, cropped_image)  

box_ratio_factors = []
sub_box_calculated = []
main_images_paths = []

def calculate_box_ratio_factor(image_path,box):
    image = cv2.imread(image_path)
    width = image.shape[0]
    height = image.shape[1]
    box[2], box[2], box[2], box[2]
    relative_xbl = box[0] #/ width
    relative_ybl = box[1] #/ height
    relative_xtr = box[2] #/ width
    relative_ytr = box[3] #/ height
    return [relative_xbl,relative_ybl,relative_xtr,relative_ytr]

def array_calculation(sub_box, main_box):
    result = []
    result.append([sub_box[0]-main_box[0],sub_box[1]-main_box[1],sub_box[2]-main_box[0],sub_box[3]-main_box[1]])

for i in range(len(main_class_ids)):
    for j in range(len(image_paths)):
        box_ratio_factors.append(calculate_box_ratio_factor(image_paths[j], main_bbox[j][i]))
        create_main_images(image_paths[j],IMAGES_MAIN_CLASSES_PATH+'/'+str(i)+'_'+str(j)+'.jpg', main_bbox[j][i])
        main_images_paths.append(IMAGES_MAIN_CLASSES_PATH+'/'+str(i)+'_'+str(j)+'.jpg')
        
count=0
for i in range(len(main_class_ids)):
    for j in range(len(image_paths)):
        sub_box_calculated.append(array_calculation(sub_bbox[j][i], main_bbox[j][i]))
        count=count+1

# %%
def create_data_tensor(image_paths,classes,bbox):
    bbox = tf.ragged.constant(bbox)
    classes = tf.ragged.constant(classes)
    image_paths = tf.ragged.constant(image_paths)
    data = tf.data.Dataset.from_tensor_slices((image_paths, classes, bbox))
    return data

# %%
data = create_data_tensor(image_paths, classes, bbox)
main_data =create_data_tensor(image_paths, main_classes, main_bbox)
sub_data = create_data_tensor(image_paths, sub_classes, sub_bbox)

# %%
def create_train_test_data(split, data_tensor):
    num_val = int(split * SPLIT_RATIO)#int(len(image_path_list)
    val_data = data_tensor.take(num_val)
    train_data = data_tensor.skip(num_val)
    return val_data, train_data

# %%
val_data, train_data = create_train_test_data(int(len(xml_files)) , data)
main_val_data, main_train_data = create_train_test_data(int(len(xml_files)) , main_data)
sub_val_data, sub_train_data = create_train_test_data(int(len(xml_files)) , sub_data)

# %%
def load_image(image_path):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)
    return image
 

def load_dataset(image_path, classes, bbox):
    # Read Image
    image = load_image(image_path)
    bounding_boxes = {
        "classes": tf.cast(classes, dtype=tf.float32),
        "boxes": bbox,
    }
    return {"images": tf.cast(image, tf.float32), "bounding_boxes": bounding_boxes}

# %%
augmenter = keras.Sequential(
    layers=[
        keras_cv.layers.RandomFlip(mode="horizontal", bounding_box_format="xyxy"),
        keras_cv.layers.JitteredResize(
            target_size=(640, 640),
            scale_factor=(0.75, 1.3),
            bounding_box_format="xyxy",
        ),
    ]
)
# Out:
# WARNING:tensorflow:From c:\Users\Tristan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
def create_train_ds(train_data):
    train_ds = train_data.map(load_dataset, num_parallel_calls=tf.data.AUTOTUNE)
    train_ds = train_ds.shuffle(BATCH_SIZE * 8)
    train_ds = train_ds.ragged_batch(BATCH_SIZE, drop_remainder=True)
    train_ds = train_ds.map(augmenter, num_parallel_calls=tf.data.AUTOTUNE)
    return train_ds

# %%
train_ds = create_train_ds(train_data)
main_train_ds = create_train_ds(main_train_data)
sub_train_ds = create_train_ds(sub_train_data)
print(main_train_ds)
# Out:
# <_ParallelMapDataset element_spec={'images': TensorSpec(shape=(2, 640, 640, 3), dtype=tf.float32, name=None), 'bounding_boxes': {'classes': RaggedTensorSpec(TensorShape([2, None]), tf.float32, 1, tf.int64), 'boxes': RaggedTensorSpec(TensorShape([2, None, None]), tf.float32, 1, tf.int64)}}>

# %%
resizing = keras_cv.layers.JitteredResize(
    target_size=(640, 640),
    scale_factor=(0.75, 1.3),
    bounding_box_format="xyxy",
)

def create_val_ds(val_data):
    val_ds = val_data.map(load_dataset, num_parallel_calls=tf.data.AUTOTUNE)
    val_ds = val_ds.shuffle(BATCH_SIZE * 8)
    val_ds = val_ds.ragged_batch(BATCH_SIZE, drop_remainder=True)
    val_ds = val_ds.map(resizing, num_parallel_calls=tf.data.AUTOTUNE)
    return val_ds

# %%
val_ds = create_train_ds(val_data)
main_val_ds = create_train_ds(main_val_data)
sub_val_ds = create_train_ds(sub_val_data)

# %%
def visualize_dataset(inputs, value_range, rows, cols, bounding_box_format):
    inputs = next(iter(inputs.take(1)))
    images, bounding_boxes = inputs["images"], inputs["bounding_boxes"]
    visualization.plot_bounding_box_gallery(
        images,
        value_range=value_range,
        rows=rows,
        cols=cols,
        y_true=bounding_boxes,
        scale=5,
        font_scale=0.2,
        bounding_box_format=bounding_box_format,
        class_mapping=class_mapping,
    )
 
 
visualize_dataset(
    sub_train_ds, bounding_box_format="xyxy", value_range=(0, 255), rows=1, cols=2
)
 
visualize_dataset(
    sub_val_ds, bounding_box_format="xyxy", value_range=(0, 255), rows=1, cols=1
)

# %%
def dict_to_tuple(inputs):
    return inputs["images"], inputs["bounding_boxes"]
 
 
train_ds = train_ds.map(dict_to_tuple, num_parallel_calls=tf.data.AUTOTUNE)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
 
val_ds = val_ds.map(dict_to_tuple, num_parallel_calls=tf.data.AUTOTUNE)
val_ds = val_ds.prefetch(tf.data.AUTOTUNE)

main_train_ds = main_train_ds.map(dict_to_tuple, num_parallel_calls=tf.data.AUTOTUNE)
main_train_ds = main_train_ds.prefetch(tf.data.AUTOTUNE)
 
main_val_ds = main_val_ds.map(dict_to_tuple, num_parallel_calls=tf.data.AUTOTUNE)
main_val_ds = main_val_ds.prefetch(tf.data.AUTOTUNE)

sub_train_ds = sub_train_ds.map(dict_to_tuple, num_parallel_calls=tf.data.AUTOTUNE)
sub_train_ds = sub_train_ds.prefetch(tf.data.AUTOTUNE)
 
sub_val_ds = sub_val_ds.map(dict_to_tuple, num_parallel_calls=tf.data.AUTOTUNE)
sub_val_ds = sub_val_ds.prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# define backbone

# %%
def define_backbone(backbone):
    backbone = keras_cv.models.YOLOV8Backbone.from_preset(
        "yolo_v8_xs_backbone_coco",
         load_weights=True 
    )
    return backbone

# %% [markdown]
# define optimizer

# %%
def define_optimizer():
    optimizer = tf.keras.optimizers.Adam(
        learning_rate=LEARNING_RATE,
        global_clipnorm=GLOBAL_CLIPNORM, #This ensures that gradients, which influence the model’s parameter updates, 
                                        # don’t become exceedingly large and destabilize training.
    )
    return optimizer

# %% [markdown]
# define YOLO8Detector

# %%
def define_model(num_classes):
    model = keras_cv.models.YOLOV8Detector(
    num_classes=num_classes, #the number of object classes
    bounding_box_format="xyxy",
    backbone=define_backbone("yolo_v8_xs_backbone_coco"),
    fpn_depth=1,
)
    return model

# %% [markdown]
# compile model

# %%
def compile_model(model):
    model.compile(
    optimizer=define_optimizer(), 
    classification_loss="binary_crossentropy", #calculates the discrepancy between anticipated class probabilities and actual class probabilities
    box_loss="ciou" # box_loss -> measure the difference between the predicted bounding boxes and the ground truth
                    # he Complete IoU (CIoU) metric is used, which not only measures the overlap between predicted and ground truth bounding 
                    # boxes but also considers the difference in aspect ratio, center distance, and box size
)

# %% [markdown]
# fit model

# %%
def fit_model(model, train_data, validation_data):
    history = model.fit(
        train_data,
        validation_data=validation_data,
        epochs=EPOCH
        #callbacks=[EvaluateCOCOMetricsCallback(val_ds, "workspace/models/yolo_coco_model.h5")],
    )
    return history

# %% [markdown]
# define NonMaxSuppression

# %%
def define_NonMaxSuppression(model):
    model.prediction_decoder = keras_cv.layers.NonMaxSuppression(
        bounding_box_format="xyxy",
        from_logits=True,
        iou_threshold=0.9,
        confidence_threshold=0.5
    
    )

# %% [markdown]
# define a base model, compile the base model and then loads the weights from a path

# %%
def load_weight_model(model_path):
    base_model = define_model(len(class_mapping))
    compile_model(base_model)
    loaded_model = base_model.load_weights(model_path)
    return  loaded_model

# %% [markdown]
# save weights of a model

# %%
def save_weights(model, name):
    save_model_path = gv_path_models + name
    model.save_weights(save_model_path)

# %% [markdown]
# define visualization methode

# %%
def visualize_detections(model, dataset, bounding_box_format, class_mapping):
    images, y_true = next(iter(dataset.take(1)))
    y_pred = model.predict(images)
    y_pred = bounding_box.to_ragged(y_pred)
    visualization.plot_bounding_box_gallery(
        images,
        value_range=(0, 255),
        bounding_box_format=bounding_box_format,
        y_true=y_true,
        y_pred=y_pred,
        scale=5,
        rows=1,
        cols=1,
        show=True,
        font_scale=0.4,
        class_mapping= class_mapping ,#class_mapping,
    )

# %% [markdown]
# define and compile model for sub_bbox

# %%
yolo_coco_sub = define_model(len(class_mapping))
compile_model(yolo_coco_sub)
# Out:
# WARNING:tensorflow:From c:\Users\Tristan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %% [markdown]
# define and compile model for main_bbox

# %%
yolo_coco_main = define_model(len(class_mapping))
compile_model(yolo_coco_main)

# %% [markdown]
# fit main_bbox_model

# %%
main_bbox_history = fit_model(yolo_coco_main, main_train_ds, main_val_ds )
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\Tristan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\Tristan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 7/7 [==============================] - 32s 935ms/step - loss: 623.5176 - box_loss: 3.0884 - class_loss: 620.4292 - val_loss: 790.0555 - val_box_loss: 4.3991 - val_class_loss: 785.6565
# Epoch 2/50
# 7/7 [==============================] - 3s 426ms/step - loss: 461.0506 - box_loss: 2.7167 - class_loss: 458.3340 - val_loss: 770.3989 - val_box_loss: 3.8883 - val_class_loss: 766.5106
# Epoch 3/50
# 7/7 [==============================] - 3s 424ms/step - loss: 1227.8777 - box_loss: 2.0893 - class_loss: 1225.7885 - val_loss: 457.4644 - val_box_loss: 3.0170 - val_class_loss: 454.4474
# Epoch 4/50
# 7/7 [==============================] - 3s 425ms/step - loss: 348.7256 - box_loss: 2.3930 - class_loss: 346.3326 - val_loss: 530.1807 - val_box_loss: 2.9358 - val_class_loss: 527.2449
# Epoch 5/50
# 7/7 [==============================] - 3s 423ms/step - loss: 4.1131 - box_loss: 1.7277 - class_loss: 2.3854 - val_loss: 7.5794 - val_box_loss: 2.7028 - val_class_loss: 4.8766
# Epoch 36/50
# 7/7 [==============================] - 3s 422ms/step - loss: 4.3685 - box_loss: 1.6776 - class_loss: 2.6910 - val_loss: 6.3055 - val_box_loss: 3.2387 - val_class_loss: 3.0668
# Epoch 37/50
# 7/7 [==============================] - 3s 421ms/step - loss: 3.7974 - box_loss: 1.4436 - class_loss: 2.3539 - val_loss: 7.0392 - val_box_loss: 3.9684 - val_class_loss: 3.0708
# Epoch 38/50
# 7/7 [==============================] - 3s 423ms/step - loss: 3.0843 - box_loss: 1.5818 - class_loss: 1.5025 - val_loss: 5.3040 - val_box_loss: 2.3446 - val_class_loss: 2.9594
# Epoch 39/50
# 7/7 [==============================] - 3s 423ms/step - loss: 2.8263 - box_loss: 1.4986 - class_loss: 1.3277 - val_loss: 2.7037 - val_box_loss: 1.4499 - val_class_loss: 1.2538
# Epoch 40/50
# 7/7 [==============================] - 3s 423ms/step - loss: 3.1295 - box_loss: 1.7887 - class_loss: 1.3408 - val_loss: 4.7235 - val_box_loss: 2.1074 - val_class_loss: 2.6161
# Epoch 41/50
# 7/7 [==============================] - 3s 426ms/step - loss: 2.6055 - box_loss: 1.3873 - class_loss: 1.2182 - val_loss: 2.2240 - val_box_loss: 1.3386 - val_class_loss: 0.8854
# Epoch 42/50
# 7/7 [==============================] - 3s 423ms/step - loss: 2.7601 - box_loss: 1.5167 - class_loss: 1.2434 - val_loss: 2.4718 - val_box_loss: 1.4406 - val_class_loss: 1.0312
# Epoch 43/50
# 7/7 [==============================] - 3s 423ms/step - loss: 3.0184 - box_loss: 1.6674 - class_loss: 1.3510 - val_loss: 2.5870 - val_box_loss: 1.6277 - val_class_loss: 0.9593
# Epoch 44/50
# 7/7 [==============================] - 3s 423ms/step - loss: 2.9330 - box_loss: 1.7048 - class_loss: 1.2282 - val_loss: 3.0745 - val_box_loss: 1.7716 - val_class_loss: 1.3029
# Epoch 45/50
# 7/7 [==============================] - 3s 422ms/step - loss: 3.3745 - box_loss: 1.5838 - class_loss: 1.7906 - val_loss: 7.4327 - val_box_loss: 2.6124 - val_class_loss: 4.8203
# Epoch 46/50
# 7/7 [==============================] - 3s 424ms/step - loss: 2.5900 - box_loss: 1.5177 - class_loss: 1.0723 - val_loss: 3.8576 - val_box_loss: 2.6991 - val_class_loss: 1.1585
# Epoch 47/50
# 7/7 [==============================] - 3s 422ms/step - loss: 3.0799 - box_loss: 1.8940 - class_loss: 1.1859 - val_loss: 2.4524 - val_box_loss: 1.5551 - val_class_loss: 0.8974
# Epoch 48/50
# 7/7 [==============================] - 3s 444ms/step - loss: 2.3599 - box_loss: 1.4460 - class_loss: 0.9139 - val_loss: 2.6936 - val_box_loss: 1.7691 - val_class_loss: 0.9245
# Epoch 49/50
# 7/7 [==============================] - 3s 429ms/step - loss: 2.6133 - box_loss: 1.3361 - class_loss: 1.2772 - val_loss: 2.2661 - val_box_loss: 1.5433 - val_class_loss: 0.7228
# Epoch 50/50
# 7/7 [==============================] - 3s 433ms/step - loss: 3.6327 - box_loss: 1.7024 - class_loss: 1.9303 - val_loss: 3.5300 - val_box_loss: 1.9403 - val_class_loss: 1.5897
# Epoch 30/50
# 7/7 [==============================] - 3s 429ms/step - loss: 3.7009 - box_loss: 1.6486 - class_loss: 2.0522 - val_loss: 3.3628 - val_box_loss: 1.9996 - val_class_loss: 1.3631
# Epoch 31/50
# 7/7 [==============================] - 3s 432ms/step - loss: 2.8861 - box_loss: 1.5294 - class_loss: 1.3568 - val_loss: 3.1322 - val_box_loss: 1.7773 - val_class_loss: 1.3549
# Epoch 32/50
# 7/7 [==============================] - 3s 435ms/step - loss: 3.2467 - box_loss: 1.6192 - class_loss: 1.6275 - val_loss: 2.4715 - val_box_loss: 1.4710 - val_class_loss: 1.0005
# Epoch 33/50
# 7/7 [==============================] - 3s 431ms/step - loss: 2.6582 - box_loss: 1.4599 - class_loss: 1.1983 - val_loss: 3.0655 - val_box_loss: 1.7092 - val_class_loss: 1.3562
# Epoch 34/50
# 7/7 [==============================] - 3s 430ms/step - loss: 2.9213 - box_loss: 1.5519 - class_loss: 1.3695 - val_loss: 3.2482 - val_box_loss: 1.8302 - val_class_loss: 1.4180
# Epoch 35/50
# 7/7 [==============================] - 3s 431ms/step - loss: 2.7499 - box_loss: 1.5093 - class_loss: 1.2406 - val_loss: 4.3014 - val_box_loss: 2.0604 - val_class_loss: 2.2410
# Epoch 36/50
# 7/7 [==============================] - 3s 433ms/step - loss: 2.5028 - box_loss: 1.4878 - class_loss: 1.0150 - val_loss: 2.7563 - val_box_loss: 1.6631 - val_class_loss: 1.0932
# Epoch 37/50
# 7/7 [==============================] - 3s 433ms/step - loss: 2.9999 - box_loss: 1.6231 - class_loss: 1.3768 - val_loss: 3.1975 - val_box_loss: 1.7329 - val_class_loss: 1.4647
# Epoch 38/50
# 7/7 [==============================] - 3s 431ms/step - loss: 2.7178 - box_loss: 1.5856 - class_loss: 1.1322 - val_loss: 2.8213 - val_box_loss: 1.4595 - val_class_loss: 1.3619
# Epoch 39/50
# 7/7 [==============================] - 3s 431ms/step - loss: 2.3520 - box_loss: 1.4787 - class_loss: 0.8733 - val_loss: 2.7903 - val_box_loss: 1.7161 - val_class_loss: 1.0741
# Epoch 40/50
# 7/7 [==============================] - 3s 433ms/step - loss: 2.4071 - box_loss: 1.4040 - class_loss: 1.0031 - val_loss: 2.7099 - val_box_loss: 1.7358 - val_class_loss: 0.9741
# Epoch 41/50
# 7/7 [==============================] - 3s 435ms/step - loss: 2.4701 - box_loss: 1.4755 - class_loss: 0.9946 - val_loss: 1.9977 - val_box_loss: 1.3473 - val_class_loss: 0.6504
# Epoch 42/50
# 7/7 [==============================] - 3s 432ms/step - loss: 2.3362 - box_loss: 1.4711 - class_loss: 0.8651 - val_loss: 2.0428 - val_box_loss: 1.3114 - val_class_loss: 0.7314
# Epoch 43/50
# 7/7 [==============================] - 3s 432ms/step - loss: 2.3044 - box_loss: 1.3637 - class_loss: 0.9407 - val_loss: 2.2368 - val_box_loss: 1.4347 - val_class_loss: 0.8021
# Epoch 44/50
# 7/7 [==============================] - 3s 433ms/step - loss: 2.3249 - box_loss: 1.3825 - class_loss: 0.9424 - val_loss: 2.3809 - val_box_loss: 1.5973 - val_class_loss: 0.7836
# Epoch 45/50
# 7/7 [==============================] - 3s 432ms/step - loss: 2.2278 - box_loss: 1.4364 - class_loss: 0.7914 - val_loss: 2.0130 - val_box_loss: 1.4396 - val_class_loss: 0.5733
# Epoch 46/50
# 7/7 [==============================] - 3s 431ms/step - loss: 2.1852 - box_loss: 1.3502 - class_loss: 0.8350 - val_loss: 2.3623 - val_box_loss: 1.4875 - val_class_loss: 0.8748
# Epoch 47/50
# 7/7 [==============================] - 3s 432ms/step - loss: 2.1391 - box_loss: 1.4280 - class_loss: 0.7110 - val_loss: 2.4674 - val_box_loss: 1.8379 - val_class_loss: 0.6295
# Epoch 48/50
# 7/7 [==============================] - 3s 434ms/step - loss: 1.9145 - box_loss: 1.3320 - class_loss: 0.5825 - val_loss: 2.3971 - val_box_loss: 1.8366 - val_class_loss: 0.5605
# Epoch 49/50
# 7/7 [==============================] - 3s 434ms/step - loss: 1.8688 - box_loss: 1.3076 - class_loss: 0.5613 - val_loss: 1.9584 - val_box_loss: 1.3929 - val_class_loss: 0.5655
# Epoch 50/50
# 7/7 [==============================] - 3s 430ms/step - loss: 1.8147 - box_loss: 1.2240 - class_loss: 0.5907 - val_loss: 2.3219 - val_box_loss: 1.8116 - val_class_loss: 0.5103

# %% [markdown]
# visualization main bbox

# %%
visualize_detections(yolo_coco_main, dataset=main_val_ds, bounding_box_format="xyxy", class_mapping= main_class_mapping)
# Out:
# 1/1 [==============================] - 1s 555ms/step

# %% [markdown]
# visualization sub bbox

# %%
visualize_detections(yolo_coco_sub, dataset=sub_val_ds, bounding_box_format="xyxy", class_mapping= sub_class_mapping)
# Out:
# 1/1 [==============================] - 3s 3s/step

# %% [markdown]
# save weights

# %%
MAIN_MODEL_PATH = gv_bbox_path+'/main_bbox_detector_model.h5'
SUB_MODEL_PATH = gv_bbox_path+'/sub_bbox_detector_model.h5'

yolo_coco_main.save_weights(MAIN_MODEL_PATH)
yolo_coco_sub.save_weights(SUB_MODEL_PATH)

# %% [markdown]
# load model for sub_bbox and visualize

# %%
yolo_coco_sub.load_weights(SUB_MODEL_PATH)

# %% [markdown]
# visualize a prediction with loaded_sub_model

# %%
visualize_detections(yolo_coco_sub, dataset=sub_val_ds, bounding_box_format="xyxy", class_mapping= sub_class_mapping)
# Out:
# 1/1 [==============================] - 0s 403ms/step

# %%
class EvaluateCOCOMetricsCallback(keras.callbacks.Callback):
    def __init__(self, data, save_path):
        super().__init__()
        self.data = data
        self.metrics = keras_cv.metrics.BoxCOCOMetrics(
            bounding_box_format="xyxy",
            evaluate_freq=1e9,
        )

        self.save_path = save_path
        self.best_map = -1.0

    def on_epoch_end(self, epoch, logs):
        self.metrics.reset_state()
        for batch in self.data:
            images, y_true = batch[0], batch[1]
            y_pred = self.model.predict(images, verbose=0)
            self.metrics.update_state(y_true, y_pred)

        metrics = self.metrics.result(force=True)
        logs.update(metrics)

        current_map = metrics["MaP"]
        if current_map > self.best_map:
            self.best_map = current_map
            self.model.save(self.save_path)  # Save the model when mAP improves

        return logs
